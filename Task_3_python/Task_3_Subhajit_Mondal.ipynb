# %% [markdown]
# ### Q1: Polar Coordinates
# ![Q1.jpg](attachment:Q1.jpg)

# %%
import cmath
c=complex(input())
for i in list(cmath.polar(c)):
    print(i)
# Out:
# 1+2j
# 2.23606797749979
# 1.1071487177940904

# %% [markdown]
# ====================================================================================================================

# %% [markdown]
# ### Q2: Triangle Quest 2
# ![Q2.jpg](attachment:Q2.jpg)

# %%
for i in range(1,int(input())+1):
    print(((10**i - 1)//9)**2)
# Out:
# 5
# 1
# 121
# 12321
# 1234321
# 123454321

# %% [markdown]
# ======================================================================================================================

# %% [markdown]
# ### Q3:Mod Divmod
# ![Q3.jpg](attachment:Q3.jpg)

# %%
a = int(input())
b = int(input())
print(a//b)
print(a%b)
print(divmod(a,b))
# Out:
# 177
# 10
# 17
# 7
# (17, 7)

# %% [markdown]
# =======================================================================================================================

# %% [markdown]
# ### Q4:Power - Mod Power
# ![Q4.jpg](attachment:Q4.jpg)

# %%
a = int(input())
b = int(input())
m = int(input())
print(pow(a,b),pow(a,b,m),sep='\n')
# Out:
# 3
# 4
# 5
# 81
# 1

# %% [markdown]
# ========================================================================================================================

# %% [markdown]
# ### Q5:Integers Come In All Sizes
# ![Q5.jpg](attachment:Q5.jpg)

# %%
a = int(input())

b = int(input())

c = int(input())

d = int(input())

print((a ** b) + (c ** d))
# Out:
# 9
# 29
# 7
# 27
# 4710194409608608369201743232

# %% [markdown]
# ========================================================================================================================

# %% [markdown]
# ### Q6:Triangle Quest
# ![Q6.jpg](attachment:Q6.jpg)

# %%
for i in range(1,int(input())): 
    print((10**(i)//9)*i)
# Out:
# 5
# 1
# 22
# 333
# 4444

# %% [markdown]
# ========================================================================================================================

# %% [markdown]
# ### Q7: Find Angle MBC
# ![Q7.jpg](attachment:Q7.jpg)

# %%
from math import *

ab = float(input())
bc = float(input())
degree=chr(176)
print(str(int(round(degrees(atan(ab/bc)),0)))+degree)
# Out:
# 10
# 10
# 45°

# %% [markdown]
# ========================================================================================================================
